# %% [markdown]
# ### fréquences de caractères
# Le code suivant permet de visualiser la fréquence des caractères présents dans le texte.

# %%
import pandas as pd
import matplotlib.pyplot as plt

NATURAL_TEXT_PATH = "./assets/accumulation-accounts-2008-2023-provisional.csv"
f= open(NATURAL_TEXT_PATH, "r")

textString = f.read()

data = {}

for char in textString :
    if(data.get(char)) :
        data[char] += 1
    else : 
        data.setdefault(char, 1)

print(data)

plt.bar(data.keys(), data.values())

plt.title("frequences des characteres")

plt.show()
# Out:
# {'P': 5305, 'e': 259564, 'r': 112052, 'i': 310935, 'o': 151952, 'd': 77897, ',': 199620, 'I': 6734, 'n': 340342, 's': 259156, 't': 218015, '_': 5, 'c': 146324, 'D': 1293, 'p': 43215, 'S': 10027, 'N': 21269, 'A': 59435, '0': 384775, '8': 16759, 'T': 7379, 'R': 10286, 'l': 155638, 'a': 288832, 'b': 43181, 'y': 13516, 'V': 1939, 'u': 83420, '\n': 33270, '2': 86730, '7': 21690, '.': 35424, '3': 55815, '-': 17099, ' ': 325601, '1': 78016, 'v': 28271, 'g': 43265, '(': 4012, ')': 4012, 'B': 2261, '+': 969, '/': 1292, 'w': 7701, '9': 14460, 'f': 35921, 'C': 26369, 'F': 57307, 'h': 36754, 'm': 25313, 'x': 7973, '4': 17492, 'q': 2584, '5': 17402, '6': 15503, 'L': 29852, 'O': 13192, 'K': 8721, 'M': 646, 'E': 7429, 'k': 4148, 'G': 646, 'H': 1751}

# %% [markdown]
# ### fréquences de groupes de characteres (taille > 2 chars)
# Le code suivant permet de visualiser la fréquence des groupes de characteres présents dans le texte. (avec max length = 20)

# %%
NATURAL_TEXT_PATH = "./assets/accumulation-accounts-2008-2023-provisional.csv"
f= open(NATURAL_TEXT_PATH, "r")

textString = f.read()

charDict = {}

sampleSize = 2

charDictFiltered = {}

while sampleSize < 20 :
    i = 0
    while i + sampleSize <= len(textString)  :
        sample = textString[i:i+sampleSize]

        if (not sample in charDict) : 
            charDict.setdefault(sample, (sampleSize, 1))
        else : 
    
            charDict[sample] = (sampleSize, charDict[sample][1] + 1)
        
        i += 1
    
    sampleSize += 1

    

    for key in charDict :
        if charDict[key][1] >= 2 :
            charDictFiltered.setdefault(key, charDict[key])

sizeCharDict = {}

for key in charDictFiltered :

   

    if (not charDictFiltered[key][0] in sizeCharDict) : 
        sizeCharDict.setdefault(charDictFiltered[key][0], charDictFiltered[key][1])
    else : 
        sizeCharDict[charDictFiltered[key][0]] += charDictFiltered[key][1]


print(sizeCharDict)

plt.bar(sizeCharDict.keys(), sizeCharDict.values())
plt.title("frequences des groupes de characteres")
plt.xticks(range(0, 21))
plt.show()
# Out:
# {2: 4297741, 3: 4297715, 4: 4296252, 5: 4291892, 6: 4287565, 7: 4281845, 8: 4266362, 9: 4247365, 10: 4228187, 11: 4209273, 12: 4185515, 13: 4157883, 14: 4135682, 15: 4114726, 16: 4093048, 17: 4068949, 18: 4040025, 19: 4009411}
